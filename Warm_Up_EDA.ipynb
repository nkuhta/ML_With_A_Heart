# %% [markdown]
# #  Exploring the Warm Up Dataset

# %%
import pandas as pd

# %%
train_values = pd.read_csv('train_values.csv')
train_labels = pd.read_csv('train_labels.csv')
test_values = pd.read_csv('test_values.csv')

# %%
#  X training dataset
train_values.head()
# Out:
#   patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0     0z64un                                  1             normal
# 1     ryoo3j                                  2             normal
# 2     yt1s1x                                  1             normal
# 3     l2xjde                                  1  reversible_defect
# 4     oyt4ek                                  3  reversible_defect
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     128                2                  0
# 1                     110                3                  0
# 2                     125                4                  3
# 3                     152                4                  0
# 4                     178                1                  0
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# 1                                     0                    0
# ...

# %%
#  Column Names
train_values.columns
# Out:
# Index(['patient_id', 'slope_of_peak_exercise_st_segment', 'thal',
#        'resting_blood_pressure', 'chest_pain_type', 'num_major_vessels',
#        'fasting_blood_sugar_gt_120_mg_per_dl', 'resting_ekg_results',
#        'serum_cholesterol_mg_per_dl', 'oldpeak_eq_st_depression', 'sex', 'age',
#        'max_heart_rate_achieved', 'exercise_induced_angina'],
#       dtype='object')

# %%
#  Column Names and data types
train_values.dtypes
# Out:
# patient_id                               object
# slope_of_peak_exercise_st_segment         int64
# thal                                     object
# resting_blood_pressure                    int64
# chest_pain_type                           int64
# num_major_vessels                         int64
# fasting_blood_sugar_gt_120_mg_per_dl      int64
# resting_ekg_results                       int64
# serum_cholesterol_mg_per_dl               int64
# oldpeak_eq_st_depression                float64
# sex                                       int64
# age                                       int64
# max_heart_rate_achieved                   int64
# exercise_induced_angina                   int64
# dtype: object

# %%
train_values.describe()
# Out:
#        slope_of_peak_exercise_st_segment  resting_blood_pressure  \
# count                         180.000000              180.000000
# mean                            1.550000              131.311111
# std                             0.618838               17.010443
# min                             1.000000               94.000000
# 25%                             1.000000              120.000000
# 50%                             1.000000              130.000000
# 75%                             2.000000              140.000000
# max                             3.000000              180.000000
#
#        chest_pain_type  num_major_vessels  \
# count       180.000000         180.000000
# mean          3.155556           0.694444
# std           0.938454           0.969347
# min           1.000000           0.000000
# 25%           3.000000           0.000000
# 50%           3.000000           0.000000
# 75%           4.000000           1.000000
# ...

# %%
#  Y values 
train_labels.head()
# Out:
#   patient_id  heart_disease_present
# 0     0z64un                      0
# 1     ryoo3j                      0
# 2     yt1s1x                      1
# 3     l2xjde                      1
# 4     oyt4ek                      0

# %%
#  Results breakdown, number of (0,1)
train_labels['heart_disease_present'].value_counts()
# Out:
# 0    100
# 1     80
# Name: heart_disease_present, dtype: int64

# %%
#  number of missing values
train_values.isnull().sum()
# Out:
# patient_id                              0
# slope_of_peak_exercise_st_segment       0
# thal                                    0
# resting_blood_pressure                  0
# chest_pain_type                         0
# num_major_vessels                       0
# fasting_blood_sugar_gt_120_mg_per_dl    0
# resting_ekg_results                     0
# serum_cholesterol_mg_per_dl             0
# oldpeak_eq_st_depression                0
# sex                                     0
# age                                     0
# max_heart_rate_achieved                 0
# exercise_induced_angina                 0
# dtype: int64

# %% [markdown]
# # Data Exploration
# ---
# *  Visually Resting BP, Fasting BS, and Serum seem to have no clear patterns of heart disease present.

# %%
import numpy as np
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
import seaborn as sns
#sns.set(style="white")
#sns.set(style="whitegrid", color_codes=True)

# %%
# %matplotlib inline
pd.crosstab(train_values.resting_blood_pressure,train_labels.heart_disease_present).plot(kind='bar')
plt.title('Heart Disease and Resting Blood Pressure')
plt.xlabel('Resting Blood Pressure')
plt.ylabel('Counts')
plt.savefig('resting_bp')

# %%
# %matplotlib inline
pd.crosstab(train_values.slope_of_peak_exercise_st_segment,train_labels.heart_disease_present).plot(kind='bar')
plt.title('Heart Disease and Slope of Peak Exercise')
plt.xlabel('Slope of Peak Exercise')
plt.ylabel('Counts')
plt.savefig('slope_peak_excercise')

# %%
# %matplotlib inline
pd.crosstab(train_values.thal,train_labels.heart_disease_present).plot(kind='bar')
plt.title('Heart Disease and Thal')
plt.xlabel('thal')
plt.ylabel('Counts')
plt.savefig('thal')

# %%
# %matplotlib inline
pd.crosstab(train_values.chest_pain_type,train_labels.heart_disease_present).plot(kind='bar')
plt.title('Heart Disease and Chest Pain Type')
plt.xlabel('Chest Pain Type')
plt.ylabel('Counts')
plt.savefig('chest_pain_type')

# %%
# %matplotlib inline
pd.crosstab(train_values.num_major_vessels,train_labels.heart_disease_present).plot(kind='bar')
plt.title('Heart Disease and Number of Major Vessels')
plt.xlabel('Number of Major Vessels')
plt.ylabel('Counts')
plt.savefig('num_maj_vessels')

# %%
# %matplotlib inline
pd.crosstab(train_values.fasting_blood_sugar_gt_120_mg_per_dl,train_labels.heart_disease_present).plot(kind='bar')
plt.title('Fasting Blood Suger GT')
plt.xlabel('Fasting Blood Suger GT')
plt.ylabel('Counts')
plt.savefig('fast_bs_gt')

# %%
# %matplotlib inline
pd.crosstab(train_values.resting_ekg_results,train_labels.heart_disease_present).plot(kind='bar')
plt.title('Resting EKG Results')
plt.xlabel('Resting EKG')
plt.ylabel('')
plt.savefig('resting_EKG')

# %%
# %matplotlib inline
pd.crosstab(train_values.oldpeak_eq_st_depression,train_labels.heart_disease_present).plot(kind='bar')
plt.title('Old Peak Eq. St. Depression')
plt.xlabel('Old peak')
plt.ylabel('EQ St Dep.')
plt.savefig('oldpeak_eq_st')

# %%
# %matplotlib inline
pd.crosstab(train_values.serum_cholesterol_mg_per_dl,train_labels.heart_disease_present).plot(kind='bar')
plt.title('Serum Cholesterol')
plt.xlabel('Serum')
plt.ylabel('Serum (mg)')
plt.savefig('serum_chol')

# %%
# %matplotlib inline
pd.crosstab(train_values.sex,train_labels.heart_disease_present).plot(kind='bar')
plt.title('Breakdown by Sex')
plt.xlabel('Sex')
plt.ylabel('Counts')
plt.savefig('sex_plot')

# %%
# %matplotlib inline
pd.crosstab(train_values.age,train_labels.heart_disease_present).plot(kind='bar')
plt.title('Breakdown by Age')
plt.xlabel('Age')
plt.ylabel('Counts')
plt.savefig('age_plot')

# %%
# %matplotlib inline
pd.crosstab(train_values.max_heart_rate_achieved,train_labels.heart_disease_present).plot(kind='bar')
plt.title('Max Heart Rate Achieved')
plt.xlabel('Heart Rate')
plt.ylabel('Counts')
plt.savefig('max_heart_rate')

# %%
# %matplotlib inline
pd.crosstab(train_values.exercise_induced_angina,train_labels.heart_disease_present).plot(kind='bar')
plt.title('Exercise induced Angina')
plt.xlabel('Induced Angina')
plt.ylabel('Counts')
plt.savefig('agina')
